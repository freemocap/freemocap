# %%
# %matplotlib WX
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\freemocap-env\lib\site-packages\matplotlib\__init__.py in __setitem__(self, key, val)
#     801             try:
# --> 802                 cval = self.validate[key](val)
#     803             except ValueError as ve:
#
# ~\anaconda3\envs\freemocap-env\lib\site-packages\matplotlib\rcsetup.py in validate_backend(s)
#     265         s if s is _auto_backend_sentinel or s.startswith("module://")
# --> 266         else _validate_standard_backends(s))
#     267     return backend
#
# ~\anaconda3\envs\freemocap-env\lib\site-packages\matplotlib\rcsetup.py in __call__(self, s)
#      63         raise ValueError('Unrecognized %s string %r: valid strings are %s'
# ---> 64                          % (self.key, s, list(self.valid.values())))
#      65
#
# ValueError: Unrecognized backend string 'gtkagg': valid strings are ['GTK3Agg', 'GTK3Cairo', 'MacOSX', 'nbAgg', 'Qt4Agg', 'Qt4Cairo', 'Qt5Agg', 'Qt5Cairo', 'TkAgg', 'TkCairo', 'WebAgg', 'WX', 'WXAgg', 'WXCairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template']
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2252/2305839510.py in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'gtk')
#
# ~\anaconda3\envs\freemocap-env\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2346                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2347             with self.builtin_trap:
# -> 2348                 result = fn(*args, **kwargs)
#    2349             return result
#    2350
#
# ~\anaconda3\envs\freemocap-env\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\envs\freemocap-env\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\anaconda3\envs\freemocap-env\lib\site-packages\IPython\core\magics\pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# ~\anaconda3\envs\freemocap-env\lib\site-packages\IPython\core\interactiveshell.py in enable_matplotlib(self, gui)
#    3528                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    3529
# -> 3530         pt.activate_matplotlib(backend)
#    3531         configure_inline_support(self, backend)
#    3532
#
# ~\anaconda3\envs\freemocap-env\lib\site-packages\IPython\core\pylabtools.py in activate_matplotlib(backend)
#     315     # the rcParam to update. This needs to be set *before* the module
#     316     # magic of switch_backend().
# --> 317     matplotlib.rcParams['backend'] = backend
#     318
#     319     # Due to circular imports, pyplot may be only partially initialised
#
# ~\anaconda3\envs\freemocap-env\lib\site-packages\matplotlib\__init__.py in __setitem__(self, key, val)
#     802                 cval = self.validate[key](val)
#     803             except ValueError as ve:
# --> 804                 raise ValueError("Key %s: %s" % (key, str(ve)))
#     805             dict.__setitem__(self, key, cval)
#     806         except KeyError:
#
# ValueError: Key backend: Unrecognized backend string 'gtkagg': valid strings are ['GTK3Agg', 'GTK3Cairo', 'MacOSX', 'nbAgg', 'Qt4Agg', 'Qt4Cairo', 'Qt5Agg', 'Qt5Cairo', 'TkAgg', 'TkCairo', 'WebAgg', 'WX', 'WXAgg', 'WXCairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template']

# %%
import numpy as np

import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
import matplotlib.animation as animation
from matplotlib.widgets import Slider
import cv2 

import copy
from pathlib import Path

#RICH CONSOLE STUFF
from rich import pretty
pretty.install() #makes all print statement output pretty
from rich import inspect
from rich.console import Console
console = Console()  
from rich.traceback import install as rich_traceback_install
from rich.markdown import Markdown

# %%
openPose3dDataPath = Path(r"C:\Users\jonma\Dropbox\FreeMoCapProject\FreeMocap_Data\sesh_2021-09-07_09_09_56\DataArrays\openPoseSkel_3d.npy")
openPose3dReprojPath = Path(r"C:\Users\jonma\Dropbox\FreeMoCapProject\FreeMocap_Data\sesh_2021-09-07_09_09_56\DataArrays\openPoseSkel_reprojErr.npy")

mediaPipe3dDataPath = Path(r"C:\Users\jonma\Dropbox\FreeMoCapProject\FreeMocap_Data\sesh_2021-09-07_09_09_56\DataArrays\mediaPipeSkel_3d.npy")
mediaPipe3dReprojPath = Path(r"C:\Users\jonma\Dropbox\FreeMoCapProject\FreeMocap_Data\sesh_2021-09-07_09_09_56\DataArrays\mediaPipeSkel_reprojErr.npy")

openPose2dDataPath = Path(r"C:\Users\jonma\Dropbox\FreeMoCapProject\FreeMocap_Data\sesh_2021-09-07_09_09_56\DataArrays\openPoseData_2d.npy")

mediaPipe2dDataPath = Path(r"C:\Users\jonma\Dropbox\FreeMoCapProject\FreeMocap_Data\sesh_2021-09-07_09_09_56\DataArrays\mediaPipe_2d.npy")

# %%
mediaPipe_nCams_nFrames_nImgPts_XYC = np.load(mediaPipe2dDataPath)

mp_rToe_conf = mediaPipe_nCams_nFrames_nImgPts_XYC[:,:,32,2].transpose()
mp_nose_conf = mediaPipe_nCams_nFrames_nImgPts_XYC[:,:,0,2].transpose()
mediaPipe_ReProjErr= np.load(mediaPipe3dReprojPath)

mediaPipe_meanReproj_fr = np.nanmean(mediaPipe_ReProjErr,0)

# %%
openPose_nCams_nFrames_nImgPts_XYC = np.load(openPose2dDataPath)

openPose_rToe_conf = openPose_nCams_nFrames_nImgPts_XYC[:,:,32,2].transpose()
openPose_nose_conf = openPose_nCams_nFrames_nImgPts_XYC[:,:,0,2].transpose()

openPose_ReProjErr= np.load(openPose3dReprojPath)
openPose_meanReproj_fr = np.nanmean(openPose_ReProjErr,0)

# %%
camLabels = ["Cam#{}".format(str(camNum)) for camNum in range(mediaPipe_nCams_nFrames_nImgPts_XYC.shape[0])]

fig1 = plt.figure()
axToe = fig1.add_subplot(1,3,1)

axToe.plot(mp_rToe_conf, label='rToe')
axToe.set_xlabel('Time (frames)')
axToe.set_ylabel('Nose Confidence')
axToe.legend()

axNose = fig1.add_subplot(1,3,2)

axNose.plot(mp_nose_conf, label='Nose')
axNose.set_xlabel('Time (frames)')
axNose.set_ylabel('Nose Confidence')
axNose.legend()

axSkelReProj = fig1.add_subplot(1,3,3)

axSkelReProj.plot(mediaPipe_meanReproj_fr, label='ReprojErr')
axSkelReProj.set_xlabel('Time (frames)')
axSkelReProj.set_ylabel('Mean ReprojErr')
axSkelReProj.legend()

plt.show()
plt.pause(.1)

# %%
fig2 = plt.figure()
axToe = fig2.add_subplot(1,3,1)

axToe.plot(openPose_rToe_conf, label='rToe')
axToe.set_xlabel('Time (frames)')
axToe.set_ylabel('Nose Confidence')
axToe.legend()

axNose = fig2.add_subplot(1,3,2)

axNose.plot(openPose_nose_conf, label='Nose')
axNose.set_xlabel('Time (frames)')
axNose.set_ylabel('Nose Confidence')
axNose.legend()

axSkelReProj = fig2.add_subplot(1,3,3)

axSkelReProj.plot(openPose_meanReproj_fr, label='ReprojErr')
axSkelReProj.set_xlabel('Time (frames)')
axSkelReProj.set_ylabel('Mean ReprojErr')
axSkelReProj.legend()

plt.show()
plt.pause(.1)
